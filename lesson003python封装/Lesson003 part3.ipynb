# %%
import frameworks as fm
#进一步将类的封装定义在frameworks当中
import numpy as np
import matplotlib.pyplot as plt
ax=plt.axes()
xlimit=10
ylimit=10
plt.axis('equal')# 等轴
plt.xlim([-xlimit,xlimit])
plt.ylim([-ylimit,ylimit])
A=fm.frame2D()
A.angle=30
A.show(ax,"A",2,"red")
B=fm.frame2D()
B.angle=0
B.center=np.array([1,1])
print(B)
B.show(ax,"B",2,"blue")
plt.show()
# Out:
# center[0 0]
# center+edge[1.  0.5]
# <frameworks.frame2D object at 0x000001C52F1E6040>
# center[1 1]
# center+edge[2. 1.]
